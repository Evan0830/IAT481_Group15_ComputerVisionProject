# %%
### Mount Google Drive ###
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
### Define root directory ###
ROOT_DIR = '/content/drive/MyDrive/IAT481-computerVisionProject'

# %%
### Install Ultralytics ###
# !pip install ultralytics

# %%
### Train model ###
import os
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=100)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 158MB/s]
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
### copy results ###

# !scp -r /content/runs/detect/train '/content/drive/MyDrive/IAT481-computerVisionProject'

# %% [markdown]
# **Prediction**

# %%
import os
from ultralytics import YOLO

# %%
model = YOLO('/content/drive/MyDrive/IAT481-computerVisionProject/train/weights/best.pt')  # load a custom model

# Predict with the model with any image from internet?
results = model('/content/drive/MyDrive/IAT481-computerVisionProject/v12044gd0000ck3o3vjc77u2r3qdfo1g.MP4', save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1285) /content/drive/MyDrive/IAT481-computerVisionProject/v12044gd0000ck3o3vjc77u2r3qdfo1g.MP4: 384x640 3 policecars, 152.5ms
# video 1/1 (frame 2/1285) /content/drive/MyDrive/IAT481-computerVisionProject/v12044gd0000ck3o3vjc77u2r3qdfo1g.MP4: 384x640 3 policecars, 128.6ms
# ...

# %%
# !scp -r /content/runs/detect/predict7 '/content/drive/MyDrive/IAT481-computerVisionProject'

# %%
# SHOW THE IMAGE STORED
# %matplotlib inline
from PIL import Image

Image.open('/content/drive/MyDrive/IAT481-computerVisionProject/predict6/D6IYNQLTZNG2TIRZLNIXGFVOCE.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x481>

# %%
model = YOLO('/content/drive/MyDrive/IAT481-computerVisionProject/train/weights/best.pt')  # load a custom model

# Predict with the model with any image from internet?
results = model('/content/drive/MyDrive/IAT481-computerVisionProject/orig-mediaitemid99623-5980.jpg', save=True)
# Out:
# image 1/1 /content/drive/MyDrive/IAT481-computerVisionProject/orig-mediaitemid99623-5980.jpg: 448x640 1 policecar, 67.6ms
# Speed: 2.7ms preprocess, 67.6ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict8

# %%
# !scp -r /content/runs/detect/predict8 '/content/drive/MyDrive/IAT481-computerVisionProject'

# %%
# SHOW THE IMAGE STORED
# %matplotlib inline
from PIL import Image

Image.open('/content/drive/MyDrive/IAT481-computerVisionProject/predict8/orig-mediaitemid99623-5980.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1163x782>

# %%
Image.open('/content/drive/MyDrive/IAT481-computerVisionProject/predict12/11857091_web1_180511-MRN-M-IMG-2045.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x800>
